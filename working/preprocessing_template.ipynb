# %% [markdown]
# https://www.kaggle.com/theoviel/improve-your-score-with-some-text-preprocessing

# %% [markdown]
# # Improve your Score with some Text Preprocessing
#
#
# This kernel is an improved version of @Dieter's work.
# > https://www.kaggle.com/christofhenkel/how-to-preprocessing-when-using-embeddings
#
#
# It is the preprocessing I use for my current LB score, and it has helped improving it by a bit. Feel free to use it as well, but please upvote if you do.
#
# This is also how I caught a glimpse of spelling mistakes in the database.
#
# #### Any feedback is appreciated !

# %%
import pandas as pd
import numpy as np
import operator 
import re

# %% [markdown]
# ## Loading data

# %%
train = pd.read_csv("../input/train.csv").drop('target', axis=1)
test = pd.read_csv("../input/test.csv")
df = pd.concat([train ,test])

print("Number of texts: ", df.shape[0])
# Out:
# Number of texts:  1362492

# %% [markdown]
# ## Loading embeddings

# %%
def load_embed(file):
    def get_coefs(word,*arr): 
        return word, np.asarray(arr, dtype='float32')
    
    if file == '../input/embeddings/wiki-news-300d-1M/wiki-news-300d-1M.vec':
        embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(file) if len(o)>100)
    else:
        embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(file, encoding='latin'))
        
    return embeddings_index

# %%
glove = '../input/embeddings/glove.840B.300d/glove.840B.300d.txt'
paragram =  '../input/embeddings/paragram_300_sl999/paragram_300_sl999.txt'
wiki_news = '../input/embeddings/wiki-news-300d-1M/wiki-news-300d-1M.vec'

# %%
print("Extracting GloVe embedding")
embed_glove = load_embed(glove)
print("Extracting Paragram embedding")
embed_paragram = load_embed(paragram)
print("Extracting FastText embedding")
embed_fasttext = load_embed(wiki_news)
# Out:
# Extracting GloVe embedding
# Extracting Paragram embedding
# Extracting FastText embedding

# %% [markdown]
# ## Vocabulary and Coverage functions
# > Again, check Dieter's work if you haven't, those are his.

# %%
def build_vocab(texts):
    sentences = texts.apply(lambda x: x.split()).values
    vocab = {}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] += 1
            except KeyError:
                vocab[word] = 1
    return vocab

# %%
def check_coverage(vocab, embeddings_index):
    known_words = {}
    unknown_words = {}
    nb_known_words = 0
    nb_unknown_words = 0
    for word in vocab.keys():
        try:
            known_words[word] = embeddings_index[word]
            nb_known_words += vocab[word]
        except:
            unknown_words[word] = vocab[word]
            nb_unknown_words += vocab[word]
            pass

    print('Found embeddings for {:.2%} of vocab'.format(len(known_words) / len(vocab)))
    print('Found embeddings for  {:.2%} of all text'.format(nb_known_words / (nb_known_words + nb_unknown_words)))
    unknown_words = sorted(unknown_words.items(), key=operator.itemgetter(1))[::-1]

    return unknown_words

# %% [markdown]
# ## Starting point

# %%
vocab = build_vocab(df['question_text'])

# %%
print("Glove : ")
oov_glove = check_coverage(vocab, embed_glove)
print("Paragram : ")
oov_paragram = check_coverage(vocab, embed_paragram)
print("FastText : ")
oov_fasttext = check_coverage(vocab, embed_fasttext)
# Out:
# Glove :
# Found embeddings for 32.77% of vocab
# Found embeddings for  88.15% of all text
# Paragram :
# Found embeddings for 19.37% of vocab
# Found embeddings for  72.21% of all text
# FastText :
# Found embeddings for 29.77% of vocab
# Found embeddings for  87.66% of all text

# %% [markdown]
#  #### Paragram seems to have a significantly lower coverage.
# >That's because it does not understand upper letters, let us lower our texts :

# %%
df['lowered_question'] = df['question_text'].apply(lambda x: x.lower())

# %%
vocab_low = build_vocab(df['lowered_question'])

# %%
print("Glove : ")
oov_glove = check_coverage(vocab_low, embed_glove)
print("Paragram : ")
oov_paragram = check_coverage(vocab_low, embed_paragram)
print("FastText : ")
oov_fasttext = check_coverage(vocab_low, embed_fasttext)
# Out:
# Glove :
# Found embeddings for 27.10% of vocab
# Found embeddings for  87.88% of all text
# Paragram :
# Found embeddings for 31.01% of vocab
# Found embeddings for  88.21% of all text
# FastText :
# Found embeddings for 21.74% of vocab
# Found embeddings for  87.14% of all text

# %% [markdown]
# #### Better, but we lost a bit of information on the other embeddings.
# > Therer are words known that are known with upper letters and unknown without. Let us fix that :
# - word.lower() takes the embedding of word if word.lower() doesn't have an embedding

# %%
def add_lower(embedding, vocab):
    count = 0
    for word in vocab:
        if word in embedding and word.lower() not in embedding:  
            embedding[word.lower()] = embedding[word]
            count += 1
    print(f"Added {count} words to embedding")

# %%
print("Glove : ")
add_lower(embed_glove, vocab)
print("Paragram : ")
add_lower(embed_paragram, vocab)
print("FastText : ")
add_lower(embed_fasttext, vocab)
# Out:
# Glove :
# Added 15199 words to embedding
# Paragram :
# Added 0 words to embedding
# FastText :
# Added 27908 words to embedding

# %%
print("Glove : ")
oov_glove = check_coverage(vocab_low, embed_glove)
print("Paragram : ")
oov_paragram = check_coverage(vocab_low, embed_paragram)
print("FastText : ")
oov_fasttext = check_coverage(vocab_low, embed_fasttext)
# Out:
# Glove :
# Found embeddings for 30.39% of vocab
# Found embeddings for  88.19% of all text
# Paragram :
# Found embeddings for 31.01% of vocab
# Found embeddings for  88.21% of all text
# FastText :
# Found embeddings for 27.77% of vocab
# Found embeddings for  87.73% of all text

# %% [markdown]
# ### What's wrong ?

# %%
oov_glove[:10]
# Out:
# [('india?', 17092),
#  ("what's", 13977),
#  ('it?', 13702),
#  ('do?', 9125),
#  ('life?', 8114),
#  ('why?', 7674),
#  ('you?', 6572),
#  ('me?', 6525),
#  ('them?', 6423),
#  ('time?', 6021)]

# %% [markdown]
# #### First faults appearing are :
# - Contractions
# - Words with punctuation in them
#
# > Let us correct that.

# %% [markdown]
# ## Contractions

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }

# %%
def known_contractions(embed):
    known = []
    for contract in contraction_mapping:
        if contract in embed:
            known.append(contract)
    return known

# %%
print("- Known Contractions -")
print("   Glove :")
print(known_contractions(embed_glove))
print("   Paragram :")
print(known_contractions(embed_paragram))
print("   FastText :")
print(known_contractions(embed_fasttext))
# Out:
# - Known Contractions -
#    Glove :
# ["can't", "'cause", "didn't", "doesn't", "don't", "I'd", "I'll", "I'm", "I've", "i'd", "i'll", "i'm", "i've", "it's", "ma'am", "o'clock", "that's", "you'll", "you're"]
#    Paragram :
# ["can't", "'cause", "didn't", "doesn't", "don't", "i'd", "i'll", "i'm", "i've", "it's", "ma'am", "o'clock", "that's", "you'll", "you're"]
#    FastText :
# []

# %% [markdown]
# #### FastText does not understand contractions
# > We use the map to replace them

# %%
def clean_contractions(text, mapping):
    specials = ["’", "‘", "´", "`"]
    for s in specials:
        text = text.replace(s, "'")
    text = ' '.join([mapping[t] if t in mapping else t for t in text.split(" ")])
    return text

# %%
df['treated_question'] = df['lowered_question'].apply(lambda x: clean_contractions(x, contraction_mapping))

# %%
vocab = build_vocab(df['treated_question'])
print("Glove : ")
oov_glove = check_coverage(vocab, embed_glove)
print("Paragram : ")
oov_paragram = check_coverage(vocab, embed_paragram)
print("FastText : ")
oov_fasttext = check_coverage(vocab, embed_fasttext)
# Out:
# Glove :
# Found embeddings for 30.53% of vocab
# Found embeddings for  88.56% of all text
# Paragram :
# Found embeddings for 31.16% of vocab
# Found embeddings for  88.58% of all text
# FastText :
# Found embeddings for 27.91% of vocab
# Found embeddings for  88.44% of all text

# %% [markdown]
# ## Now, let us deal with special characters

# %%
punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'

# %%
def unknown_punct(embed, punct):
    unknown = ''
    for p in punct:
        if p not in embed:
            unknown += p
            unknown += ' '
    return unknown

# %%
print("Glove :")
print(unknown_punct(embed_glove, punct))
print("Paragram :")
print(unknown_punct(embed_paragram, punct))
print("FastText :")
print(unknown_punct(embed_fasttext, punct))
# Out:
# Glove :
# “ ” ’ ∞ θ ÷ α • à − β ∅ ³ π ‘ ₹ ´ ° £ € × ™ √ ² — –
# Paragram :
# “ ” ’ ∞ θ ÷ α • à − β ∅ ³ π ‘ ₹ ´ ° £ € × ™ √ ² — –
# FastText :
# _ `

# %% [markdown]
# #### FastText seems to have a better knowledge of special characters
# > We use a map to replace unknown characters with known ones.
#
# > We make sure there are spaces between words and punctuation

# %%
punct_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2", "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', }

# %%
def clean_special_chars(text, punct, mapping):
    for p in mapping:
        text = text.replace(p, mapping[p])
    
    for p in punct:
        text = text.replace(p, f' {p} ')
    
    specials = {'\u200b': ' ', '…': ' ... ', '\ufeff': '', 'करना': '', 'है': ''}  # Other special characters that I have to deal with in last
    for s in specials:
        text = text.replace(s, specials[s])
    
    return text

# %%
df['treated_question'] = df['treated_question'].apply(lambda x: clean_special_chars(x, punct, punct_mapping))

# %%
vocab = build_vocab(df['treated_question'])
print("Glove : ")
oov_glove = check_coverage(vocab, embed_glove)
print("Paragram : ")
oov_paragram = check_coverage(vocab, embed_paragram)
print("FastText : ")
oov_fasttext = check_coverage(vocab, embed_fasttext)
# Out:
# Glove :
# Found embeddings for 69.10% of vocab
# Found embeddings for  99.58% of all text
# Paragram :
# Found embeddings for 73.58% of vocab
# Found embeddings for  99.63% of all text
# FastText :
# Found embeddings for 60.75% of vocab
# Found embeddings for  99.45% of all text

# %%
oov_fasttext[:100]
# Out:
# [('quorans', 885),
#  ('bitsat', 583),
#  ('kvpy', 369),
#  ('comedk', 369),
#  ('quoran', 325),
#  ('wbjee', 246),
#  ('articleship', 218),
#  ('viteee', 193),
#  ('fortnite', 166),
#  ('upes', 164),
#  ('marksheet', 151),
#  ('afcat', 131),
#  ('uceed', 126),
#  ('dropshipping', 123),
#  ('bhakts', 118),
#  ('iitjee', 114),
#  ('machedo', 112),
#  ('upsee', 111),
#  ('bnbr', 105),
#  ('alshamsi', 100),
#  ('chsl', 100),
#  ('iitian', 99),
#  ('amcat', 97),
#  ('josaa', 96),
#  ('unacademy', 89),
#  ('zerodha', 85),
#  ('qoura', 85),
#  ('nmat', 80),
#  ('icos', 79),
#  ('jiit', 78),
#  ('hairfall', 73),
#  ('lnmiit', 73),
#  ('metoo', 71),
#  ('kavalireddi', 71),
#  ('doklam', 70),
#  ('muoet', 68),
#  ('woocommerce', 67),
#  ('nicmar', 66),
#  ('vajiram', 62),
#  ('srmjee', 61),
#  ('modiji', 61),
#  ('infjs', 60),
#  ('adhaar', 60),
#  ('zebpay', 58),
#  ('elitmus', 58),
#  ('pubg', 57),
#  ('awdhesh', 55),
#  ('hackerrank', 54),
#  ('gixxer', 54),
#  ('aiq', 53),
#  ('sibm', 53),
#  ('koinex', 50),
#  ('golang', 50),
#  ('mahadasha', 49),
#  ('mhcet', 47),
#  ('byju', 47),
#  ('binance', 46),
#  ('srmjeee', 44),
#  ('playstore', 44),
#  ('mnit', 43),
#  ('ftre', 42),
#  ('skripal', 42),
#  ('sgsits', 42),
#  ('howdo', 41),
#  ('mhtcet', 40),
#  ('tatkal', 40),
#  ('whatare', 39),
#  ('bipc', 39),
#  ('lbsnaa', 38),
#  ('mastrubation', 38),
#  ('pdpu', 38),
#  ('bmsce', 38),
#  ('jiofi', 38),
#  ('nanodegree', 38),
#  ('upse', 37),
#  ('jbims', 37),
#  ('sarahah', 36),
#  ('tanx', 36),
#  ('pcod', 35),
#  ('daiict', 35),
#  ('youtu', 34),
#  ('usict', 34),
#  ('reactjs', 34),
#  ('dushka', 34),
#  ('aits', 33),
#  ('nchmct', 33),
#  ('iisers', 33),
#  ('bittrex', 32),
#  ('cdse', 31),
#  ('pessat', 31),
#  ('infps', 31),
#  ('diestm', 31),
#  ('codechef', 31),
#  ('swiggy', 31),
#  ('xxxtentacion', 30),
#  ('passouts', 30),
#  ('mppsc', 30),
#  ('dream11', 30),
#  ('demonitisation', 30),
#  ('galgotia', 29)]

# %% [markdown]
# ### What's still missing ?
# - Unknown words
# - Acronyms
# - Spelling mistakes

# %% [markdown]
# ## We can correct manually most frequent mispells

# %% [markdown]
# #### For example, here are some mistakes and their frequency
# - qoura : 85 times
# - mastrubation : 38 times
# - demonitisation : 30 times
# - …

# %%
mispell_dict = {'colour': 'color', 'centre': 'center', 'favourite': 'favorite', 'travelling': 'traveling', 'counselling': 'counseling', 'theatre': 'theater', 'cancelled': 'canceled', 'labour': 'labor', 'organisation': 'organization', 'wwii': 'world war 2', 'citicise': 'criticize', 'youtu ': 'youtube ', 'Qoura': 'Quora', 'sallary': 'salary', 'Whta': 'What', 'narcisist': 'narcissist', 'howdo': 'how do', 'whatare': 'what are', 'howcan': 'how can', 'howmuch': 'how much', 'howmany': 'how many', 'whydo': 'why do', 'doI': 'do I', 'theBest': 'the best', 'howdoes': 'how does', 'mastrubation': 'masturbation', 'mastrubate': 'masturbate', "mastrubating": 'masturbating', 'pennis': 'penis', 'Etherium': 'Ethereum', 'narcissit': 'narcissist', 'bigdata': 'big data', '2k17': '2017', '2k18': '2018', 'qouta': 'quota', 'exboyfriend': 'ex boyfriend', 'airhostess': 'air hostess', "whst": 'what', 'watsapp': 'whatsapp', 'demonitisation': 'demonetization', 'demonitization': 'demonetization', 'demonetisation': 'demonetization'}

# %%
def correct_spelling(x, dic):
    for word in dic.keys():
        x = x.replace(word, dic[word])
    return x

# %%
df['treated_question'] = df['treated_question'].apply(lambda x: correct_spelling(x, mispell_dict))

# %%
vocab = build_vocab(df['treated_question'])
print("Glove : ")
oov_glove = check_coverage(vocab, embed_glove)
print("Paragram : ")
oov_paragram = check_coverage(vocab, embed_paragram)
print("FastText : ")
oov_fasttext = check_coverage(vocab, embed_fasttext)
# Out:
# Glove :
# Found embeddings for 69.09% of vocab
# Found embeddings for  99.58% of all text
# Paragram :
# Found embeddings for 73.58% of vocab
# Found embeddings for  99.63% of all text
# FastText :
# Found embeddings for 60.74% of vocab
# Found embeddings for  99.45% of all text

# %% [markdown]
# ### That's all for now !
#
# #### Improvement ideas:
# > Replace acronyms with their meaning
#
# > Replace unknown words with a more general term :
#  - ex : fortnite, pubg -> video game
#
#  ### *Thanks for reading ! *

# %%
insincere_questions = df.sort_values('question_text', ascending=True)
insincere_questions[:100]
# Out:
#                           qid  \
# 840731   a4c44963530035288b93
# 613283   781b002c109bfc37d8e6
# 420816   527aac2ce6f12f789fe5
# 1102919  d827932261abbd74fc45
# 213438   29c09eb5311f71b0809d
# 496717   614361b1ee8b7d82876e
# 646127   7e8c70c6cc622e84160e
# 4692     00e9f7cd3e8d60b309fb
# 998382   c3a539c771f3b20256c6
# 387244   4bdd5ebef6ceb1b47651
# 567223   6f240538ec0d117be8ad
# 1205297  ec3f65b04d6d1e2c183c
# 1067128  d11a60b0edfe9a270bf3
# 255483   31ff8ca723b8de558454
# 142967   1bfaa71dee96f0a4fe9a
# 1181663  e78fb2be7683014b0365
# 976683   bf5980d91b421f9f05e7
# 1037126  cb3971a28da59e4e0241
# 256282   322a5fd29815b9b41807
# 1111541  d9cfeca36f83f12b2212
# 747556   9271ad4f691bd0971daf
# 471849   5c6568c65ce8cacd9f18
# 677382   84a7a11773b2734df2c5
# 190942   25551900d3fd7cdef2d4
# 1172612  e5c966735cb11638407a
# 616695   78c450e1e2ffa55f145e
# 923525   b4fbce1d18c840701d63
# 723217   8d984587f8458d600285
# 173991   22062c33ea9847f33516
# 290117   38d2710de92629dc0f81
# ...                       ...
# 1087329  d51274885d4800aad61f
# 618400   7919c5bffae3d7f0c27b
# 457323   599410be3d2d63abe39c
# 365512   47a7eac5a003084f35d2
# 1304943  ffc57d7cab5e3c54f90b
# 84526    108d56175b28e1297b0b
# 478578   5db77b0ec693942cceed
# 708213   8aa8ea70802844b077e1
# 597936   751ed08a7e9954c828e0
# 381574   4ac97e79ae9aaedbdea9
# 575150   70b176531c729fecdaee
# 1286077  fc0b9ff7b39c91fca647
# 821301   a0eea7a56060ead1894c
# 661250   8185cd0d55cd0d4e6d3e
# 842633   a524c763a7baad493dd3
# 540079   69d092a08faf174cf0da
# 32778    066aafd66e035a3812be
# 1287655  fc5a1fb0e0f2ab14f3b0
# 587799   73268184e56a42a4ba14
# 1140103  df69bbbd3392eb030a6b
# 218976   2ad6100f1662ed7e76e8
# 1288731  fc91bf3c3c6c105996ef
# 693025   87beebe03a78d29f3a8a
# 313434   3d693ccd393dcb3a7313
# 1171132  e581e23ee8921860be22
# 704516   89f2fa97f4524bf3f2ba
# 493774   60aeecf2fb542dd1eb82
# 1050664  cde03b69bbe12eb2c932
# 1279174  fab2916368b8084bd3f6
# 550556   6bdecb5e4fa17f69e127
#
#                                              question_text  \
# 840731        I want to blow things up with TNT now what?
# 613283   !TRIGGER WARNING! Am I a homophobe if I refuse...
# 420816                                                   "
# 1102919  " I post a download link of a website in my we...
# 213438   " I visited the theater" or "I enjoyed the the...
# 496717   " I've been to the doctor many times now to cu...
# 646127   " Is there anybody who had drastic good / bad ...
# 4692     " So far She has published three chapters of h...
# 998382   " What does the scientific mean when you dream...
# 387244   " if 25 men working 6 hrs a day, can do a work...
# 567223   " why the people of France were not satisfied ...
# 1205297                      "#@! %*" what is the meaning?
# 1067128    "1+1 = 2." In how many ways can you explain it?
# 255483   "14th FC delivered a strong push towards true ...
# 142967   "A country cracking from outside pressure, dis...
# 1181663  "A fruit is green when unripe but becomes colo...
# 976683   "A lower wet bulb temperature means the air is...
# 1037126  "A map is only useful if it simplifies things?...
# 256282   "A moon will rise from my darkness" What does ...
# 1111541  "A myriad" or "myriads"? (both phrases are fea...
# 747556   "A rule is a rule even for a fool", how well i...
# 471849   "A square is always a rectangle but a rectangl...
# 677382   "A:I love your dress.B: Thank you.I've been sa...
# 190942   "Action and reaction forces are equal in magni...
# 1172612  "After my election I'll have more flexibility....
# 616695   "All 50 men has completed their tasks" or "all...
# 923525   "All countries support Indian Army to occupy C...
# 723217   "All countries support Indian Army to occupy C...
# 173991   "All men are created equal", did the Founding ...
# 290117   "All those who believe in the Lord Jesus, why ...
# ...                                                    ...
# 1087329  "Dead cannot rule the living", then why the 15...
# 618400   "Democracy is as effective as the level of edu...
# 457323   "Depression and obsession doesn't mix well" sh...
# 365512   "Did/had + subject + verb + object"this kind o...
# 1304943  "Disempathetic Sociopathy". Does it really exist?
# 84526    "Dolce gabbana paya, armani leke aaya." What i...
# 478578   "Donations" in return for something or a favor...
# 708213   "Don’t underestimate the power of people. Netw...
# 597936   "Each of the boys" or "each of the boy", which...
# 381574   "Each segment of sea is listed as pairs of add...
# 575150   "Earning rises as your market share does." Doe...
# 1286077  "Elijah went up by a whirlwind into heaven," 2...
# 821301   "Energy exists in two states: matter and radia...
# 661250   "Even with a subsidy on healthy foods, a fat t...
# 842633   "Every Person or group who's dissatisfied with...
# 540079   "Every need got an ego to feed" Pumper's Parad...
# 32778    "Everything the left touches gets corrupted." ...
# 1287655  "Everytime she has punished me I didn't deserv...
# 587799   "Evil communication corrupts good manners" (1C...
# 1140103  "Expecting black students to keep up academica...
# 218976   "Experts" claim that humans will be marrying r...
# 1288731  "Fake friends help you up when you fall. Real ...
# 693025   "Fame doesn't matter, what matters is you." Ho...
# 313434           "Felicia + Janice" or "Janice + Felicia"?
# 1171132  "Fetus" was coined in the 1500s, when people w...
# 704516   "Finally you're here.Where have you been? I ca...
# 493774   "Freedom of religion and religion has been use...
# 1050664  "Gamenights.stream" is this domain worth 3 dol...
# 1279174  "Get more followers on Instagram using our gen...
# 550556   "Gingko biloba", can I just take it ? Or shoul...
#
#                                           lowered_question  \
# 840731        i want to blow things up with tnt now what?
# 613283   !trigger warning! am i a homophobe if i refuse...
# 420816                                                   "
# 1102919  " i post a download link of a website in my we...
# 213438   " i visited the theater" or "i enjoyed the the...
# 496717   " i've been to the doctor many times now to cu...
# 646127   " is there anybody who had drastic good / bad ...
# 4692     " so far she has published three chapters of h...
# 998382   " what does the scientific mean when you dream...
# 387244   " if 25 men working 6 hrs a day, can do a work...
# 567223   " why the people of france were not satisfied ...
# 1205297                      "#@! %*" what is the meaning?
# 1067128    "1+1 = 2." in how many ways can you explain it?
# 255483   "14th fc delivered a strong push towards true ...
# 142967   "a country cracking from outside pressure, dis...
# 1181663  "a fruit is green when unripe but becomes colo...
# 976683   "a lower wet bulb temperature means the air is...
# 1037126  "a map is only useful if it simplifies things?...
# 256282   "a moon will rise from my darkness" what does ...
# 1111541  "a myriad" or "myriads"? (both phrases are fea...
# 747556   "a rule is a rule even for a fool", how well i...
# 471849   "a square is always a rectangle but a rectangl...
# 677382   "a:i love your dress.b: thank you.i've been sa...
# 190942   "action and reaction forces are equal in magni...
# 1172612  "after my election i'll have more flexibility....
# 616695   "all 50 men has completed their tasks" or "all...
# 923525   "all countries support indian army to occupy c...
# 723217   "all countries support indian army to occupy c...
# 173991   "all men are created equal", did the founding ...
# 290117   "all those who believe in the lord jesus, why ...
# ...                                                    ...
# 1087329  "dead cannot rule the living", then why the 15...
# 618400   "democracy is as effective as the level of edu...
# 457323   "depression and obsession doesn't mix well" sh...
# 365512   "did/had + subject + verb + object"this kind o...
# 1304943  "disempathetic sociopathy". does it really exist?
# 84526    "dolce gabbana paya, armani leke aaya." what i...
# 478578   "donations" in return for something or a favor...
# 708213   "don’t underestimate the power of people. netw...
# 597936   "each of the boys" or "each of the boy", which...
# 381574   "each segment of sea is listed as pairs of add...
# 575150   "earning rises as your market share does." doe...
# 1286077  "elijah went up by a whirlwind into heaven," 2...
# 821301   "energy exists in two states: matter and radia...
# 661250   "even with a subsidy on healthy foods, a fat t...
# 842633   "every person or group who's dissatisfied with...
# 540079   "every need got an ego to feed" pumper's parad...
# 32778    "everything the left touches gets corrupted." ...
# 1287655  "everytime she has punished me i didn't deserv...
# 587799   "evil communication corrupts good manners" (1c...
# 1140103  "expecting black students to keep up academica...
# 218976   "experts" claim that humans will be marrying r...
# 1288731  "fake friends help you up when you fall. real ...
# 693025   "fame doesn't matter, what matters is you." ho...
# 313434           "felicia + janice" or "janice + felicia"?
# 1171132  "fetus" was coined in the 1500s, when people w...
# 704516   "finally you're here.where have you been? i ca...
# 493774   "freedom of religion and religion has been use...
# 1050664  "gamenights.stream" is this domain worth 3 dol...
# 1279174  "get more followers on instagram using our gen...
# 550556   "gingko biloba", can i just take it ? or shoul...
#
#                                           treated_question
# 840731      i want to blow things up with tnt now what ?
# 613283    ! trigger warning !  am i a homophobe if i re...
# 420816                                                 "
# 1102919    "   i post a download link of a website in m...
# 213438     "   i visited the theater  "   or   "  i enj...
# 496717     "   i have been to the doctor many times now...
# 646127     "   is there anybody who had drastic good   ...
# 4692       "   so far she has published three chapters ...
# 998382     "   what does the scientific mean when you d...
# 387244     "   if 25 men working 6 hrs a day ,  can do ...
# 567223     "   why the people of france were not satisf...
# 1205297    "   #  @  !   %  *   "   what is the meaning ?
# 1067128    "  1 + 1  =  2 .   "   in how many ways can ...
# 255483     "  14th fc delivered a strong push towards t...
# 142967     "  a country cracking from outside pressure ...
# 1181663    "  a fruit is green when unripe but becomes ...
# 976683     "  a lower wet bulb temperature means the ai...
# 1037126    "  a map is only useful if it simplifies thi...
# 256282     "  a moon will rise from my darkness  "   wh...
# 1111541    "  a myriad  "   or   "  myriads  "   ?   ( ...
# 747556     "  a rule is a rule even for a fool  "   ,  ...
# 471849     "  a square is always a rectangle but a rect...
# 677382     "  a : i love your dress . b :  thank you . ...
# 190942     "  action and reaction forces are equal in m...
# 1172612    "  after my election i will have more flexib...
# 616695     "  all 50 men has completed their tasks  "  ...
# 923525     "  all countries support indian army to occu...
# 723217     "  all countries support indian army to occu...
# 173991     "  all men are created equal  "   ,  did the...
# 290117     "  all those who believe in the lord jesus ,...
# ...                                                    ...
# 1087329    "  dead cannot rule the living  "   ,  then ...
# 618400     "  democracy is as effective as the level of...
# 457323     "  depression and obsession does not mix wel...
# 365512     "  did  /  had  +  subject  +  verb  +  obje...
# 1304943    "  disempathetic sociopathy  "   .  does it ...
# 84526      "  dolce gabbana paya ,  armani leke aaya . ...
# 478578     "  donations  "   in return for something or...
# 708213     "  don  '  t underestimate the power of peop...
# 597936     "  each of the boys  "   or   "  each of the...
# 381574     "  each segment of sea is listed as pairs of...
# 575150     "  earning rises as your market share does ....
# 1286077    "  elijah went up by a whirlwind into heaven...
# 821301     "  energy exists in two states :  matter and...
# 661250     "  even with a subsidy on healthy foods ,  a...
# 842633     "  every person or group who is dissatisfied...
# 540079     "  every need got an ego to feed  "   pumper...
# 32778      "  everything the left touches gets corrupte...
# 1287655    "  everytime she has punished me i did not d...
# 587799     "  evil communication corrupts good manners ...
# 1140103    "  expecting black students to keep up acade...
# 218976     "  experts  "   claim that humans will be ma...
# 1288731    "  fake friends help you up when you fall . ...
# 693025     "  fame does not matter ,  what matters is y...
# 313434     "  felicia  +  janice  "   or   "  janice  +...
# 1171132    "  fetus  "   was coined in the 1500s ,  whe...
# 704516     "  finally you are here . where have you bee...
# 493774     "  freedom of religion and religion has been...
# 1050664    "  gamenights . stream  "   is this domain w...
# 1279174    "  get more followers on instagram using our...
# 550556     "  gingko biloba  "   ,  can i just take it ...
#
# [100 rows x 4 columns]

# %%
insincere_questions[100:]
# Out:
#                           qid  \
# 452809   58b2b29b905f87374b0d
# 841088   a4d85947da93238104c6
# 78695    0f67b063fca55bb64c41
# 500188   61ee3e65947056a8d6d9
# 191134   255e742e6e41a0923f45
# 466553   5b5c6fd69d916fde70ab
# 679550   8516e378d96649bf3beb
# 1161271  e38a862416e7cc224aa7
# 46151    d0d9f8d46ed51d7df2a5
# 309560   3ca315c28b23485e1989
# 643506   7e07fe9287f2399f404e
# 742890   9180c353ffa2d069fe00
# 24806    701b0ec4b945585d102c
# 1229319  f0e844f4416a6b1341f6
# 706474   8a559b9b1618478f98c3
# 107536   150e84ffee2e885c6e6f
# 949781   ba1c34d9dc5b86c9e486
# 274742   35c514db8c9fdbdfaa01
# 424217   532776444ac709409dbb
# 84642    10931a6626830da6dcae
# 33086    067a8419d230f69a31eb
# 1208967  ecf294f268232ecadcc2
# 659354   812885446306edfc9be9
# 1291406  fd19ef97feed6c6b7a52
# 864249   a957bfd7d591828dc9c0
# 881585   acb73c162d109e202f29
# 882646   aceadb7787cdb8fe5180
# 586528   72e6fd01e33a9ef46b45
# 654137   80216e7241fa31420651
# 720041   8cf4a7588cfbc8a67df5
# ...                       ...
# 737509   906eef1e877826b3bfdb
# 1206740  ec8723123beaba67ecaf
# 20319    03f9efba9bf154856463
# 181887   238c1111a53d11d79032
# 1304977  ffc6ff88d220770f401c
# 792503   9b4b15c25d95ffd6bd93
# 1151443  e19cbb74c08a685cbf3f
# 1196897  ea95e5adcafa87d2e2a9
# 150532   1d6f0f933ac6485b7c36
# 495724   611286c3a82ef4501bcb
# 517764   65638be1c7890676347e
# 1263890  f7affcf4b77cd9ed50fb
# 932272   b6b2d73b2affd31ec3b0
# 400329   4e6e06db4050cdd0f1e0
# 849182   a6606b8b3010711ca787
# 171612   218ba5a072d4da2cfd18
# 56896    0b2a246abb20bdf97606
# 756223   942af14d6de7a176d6ea
# 82007    100f35894f9a2ffe3e32
# 113435   1630ae978508b78771cd
# 56298    ffa86ce88161ba844439
# 146277   1c9bc1186127f63e61c8
# 859955   a87bd0569eacd5a477ed
# 1185049  e83bf7ee6d26a322200c
# 415446   516784a8d549d17f4aa7
# 231111   2d332fda4589c8d08526
# 814877   9fa9da7c7446a1865a37
# 916459   b390d8bdb1ae35274aa7
# 1261734  f7432bd5408af6e85526
# 344918   4394a198d685840a276f
#
#                                              question_text  \
# 452809   "Go West Young Man", where and when it came from?
# 841088   "God destroys the upright and the perfect", if...
# 78695    "God is at once a Spirit yet can also become i...
# 500188   "Grand Theft Auto V" features a newly drawn ma...
# 191134   "Guestofaguest" does anyone subscribe to it? I...
# 466553   "Hard work beats talent when talent doesn't wo...
# 679550   "Have you been practicing any sport these year...
# 1161271  "Have you ever laughed very badly in your sadn...
# 46151    "Have you ever loved someone truly or madly or...
# 309560   "He was fooling us all this time.He bought all...
# 643506   "He will die. Will we all not?" Why does "not"...
# 742890      "He will have been eating food" is it correct?
# 24806    "He's so little for me" what did Dany mean tha...
# 1229319  "He's three and oh". What does it mean at the ...
# 706474   "Heavy rain prevented us to go to the cinema."...
# 107536   "Help people that are suffering", is this sent...
# 949781   "Hi, From last 3.5 years I am working and now ...
# 274742   "His heart is bigger than his head". How can I...
# 424217   "His name 'is' John. He 'is' kind. He 'is' cur...
# 84642    "History is the root and politics is the fruit...
# 33086    "Holocaust survivor" is someone who "sur" "viv...
# 1208967  "How Christians see Jews in United States and ...
# 659354   "How can I create a script with python that se...
# 1291406  "How can I get chance to play in Ranji or dome...
# 864249   "How can I give ICSE again if do not get good ...
# 881585   "How can I write national voter day in good ha...
# 882646   "How can some people say that their ALS is rev...
# 586528   "How do you start a succesful business online,...
# 654137   "How many weeks can the onion juice stay, with...
# 720041   "How to "get rid off of your unhappy past memo...
# ...                                                    ...
# 737509   • What kind of bullying is there? Is there onl...
# 1206740  • What political and social theories from the ...
# 20319    • Which is the best tour operator for South In...
# 181887   • Which sentences refer to events that were fi...
# 1304977         • Why do we use units such as light years?
# 792503                                   • why men harass?
# 1151443  … Are you qualified that we may believe you? O...
# 1196897  … What are you doing with all this easy math p...
# 150532   ‪Does anyone know of an iOS email client that ...
# 495724   ‪How much do China or the USA will bid to buy ...
# 517764   ‪If a picture is worth a thousand words, does ...
# 1263890  ‪If an automated car violates traffic rules, s...
# 932272   ‪If you join the people your political leaders...
# 400329   ‪Is Theresa May the most stupid Prime Minister...
# 849182   ‪There are many LGBT couples trying to adopt k...
# 171612   ‪What are the best scientific evidences and id...
# 56896    ‪What in your opinion are the greatest opening...
# 756223     ‪What is the position of the EU regarding ICOs?
# 82007    ‪Where do I go to find people who will talk co...
# 113435   ⁠⁠Is it bad to lay your motorcycle on its side...
# 56298          ∅⊂ {∅} is true while 1 ⊆ {1} is false, why?
# 146277                     −6.175 is an irrational number?
# 859955   ♣ Why does Winston finally give in to the ideo...
# 1185049  ⦁ What are the methods used to suppress or red...
# 415446   译文 who well be enter the next member of the st...
# 231111                                 한국 고등학교는 몇시간 수업하니까?
# 814877             what is the Complex compound sentence?
# 916459   ﻿What are the best porn pictures serving websi...
# 1261734  Ｈow do I find the negative solution of 4^x = x...
# 344918   ￼￼Assuming that a lightning bolt can be modell...
#
#                                           lowered_question  \
# 452809   "go west young man", where and when it came from?
# 841088   "god destroys the upright and the perfect", if...
# 78695    "god is at once a spirit yet can also become i...
# 500188   "grand theft auto v" features a newly drawn ma...
# 191134   "guestofaguest" does anyone subscribe to it? i...
# 466553   "hard work beats talent when talent doesn't wo...
# 679550   "have you been practicing any sport these year...
# 1161271  "have you ever laughed very badly in your sadn...
# 46151    "have you ever loved someone truly or madly or...
# 309560   "he was fooling us all this time.he bought all...
# 643506   "he will die. will we all not?" why does "not"...
# 742890      "he will have been eating food" is it correct?
# 24806    "he's so little for me" what did dany mean tha...
# 1229319  "he's three and oh". what does it mean at the ...
# 706474   "heavy rain prevented us to go to the cinema."...
# 107536   "help people that are suffering", is this sent...
# 949781   "hi, from last 3.5 years i am working and now ...
# 274742   "his heart is bigger than his head". how can i...
# 424217   "his name 'is' john. he 'is' kind. he 'is' cur...
# 84642    "history is the root and politics is the fruit...
# 33086    "holocaust survivor" is someone who "sur" "viv...
# 1208967  "how christians see jews in united states and ...
# 659354   "how can i create a script with python that se...
# 1291406  "how can i get chance to play in ranji or dome...
# 864249   "how can i give icse again if do not get good ...
# 881585   "how can i write national voter day in good ha...
# 882646   "how can some people say that their als is rev...
# 586528   "how do you start a succesful business online,...
# 654137   "how many weeks can the onion juice stay, with...
# 720041   "how to "get rid off of your unhappy past memo...
# ...                                                    ...
# 737509   • what kind of bullying is there? is there onl...
# 1206740  • what political and social theories from the ...
# 20319    • which is the best tour operator for south in...
# 181887   • which sentences refer to events that were fi...
# 1304977         • why do we use units such as light years?
# 792503                                   • why men harass?
# 1151443  … are you qualified that we may believe you? o...
# 1196897  … what are you doing with all this easy math p...
# 150532   ‪does anyone know of an ios email client that ...
# 495724   ‪how much do china or the usa will bid to buy ...
# 517764   ‪if a picture is worth a thousand words, does ...
# 1263890  ‪if an automated car violates traffic rules, s...
# 932272   ‪if you join the people your political leaders...
# 400329   ‪is theresa may the most stupid prime minister...
# 849182   ‪there are many lgbt couples trying to adopt k...
# 171612   ‪what are the best scientific evidences and id...
# 56896    ‪what in your opinion are the greatest opening...
# 756223     ‪what is the position of the eu regarding icos?
# 82007    ‪where do i go to find people who will talk co...
# 113435   ⁠⁠is it bad to lay your motorcycle on its side...
# 56298          ∅⊂ {∅} is true while 1 ⊆ {1} is false, why?
# 146277                     −6.175 is an irrational number?
# 859955   ♣ why does winston finally give in to the ideo...
# 1185049  ⦁ what are the methods used to suppress or red...
# 415446   译文 who well be enter the next member of the st...
# 231111                                 한국 고등학교는 몇시간 수업하니까?
# 814877             what is the complex compound sentence?
# 916459   ﻿what are the best porn pictures serving websi...
# 1261734  ｈow do i find the negative solution of 4^x = x...
# 344918   ￼￼assuming that a lightning bolt can be modell...
#
#                                           treated_question
# 452809     "  go west young man  "   ,  where and when ...
# 841088     "  god destroys the upright and the perfect ...
# 78695      "  god is at once a spirit yet can also beco...
# 500188     "  grand theft auto v  "   features a newly ...
# 191134     "  guestofaguest  "   does anyone subscribe ...
# 466553     "  hard work beats talent when talent does n...
# 679550     "  have you been practicing any sport these ...
# 1161271    "  have you ever laughed very badly in your ...
# 46151      "  have you ever loved someone truly or madl...
# 309560     "  he was fooling us all this time . he boug...
# 643506     "  he will die .  will we all not ?   "   wh...
# 742890     "  he will have been eating food  "   is it ...
# 24806      "  he  '  s so little for me  "   what did d...
# 1229319    "  he  '  s three and oh  "   .  what does i...
# 706474     "  heavy rain prevented us to go to the cine...
# 107536     "  help people that are suffering  "   ,  is...
# 949781     "  hi ,  from last 3 . 5 years i am working ...
# 274742     "  his heart is bigger than his head  "   . ...
# 424217     "  his name   '  is  '   john .  he   '  is ...
# 84642      "  history is the root and politics is the f...
# 33086      "  holocaust survivor  "   is someone who   ...
# 1208967    "  how christians see jews in united states ...
# 659354     "  how can i create a script with python tha...
# 1291406    "  how can i get chance to play in ranji or ...
# 864249     "  how can i give icse again if do not get g...
# 881585     "  how can i write national voter day in goo...
# 882646     "  how can some people say that their als is...
# 586528     "  how do you start a succesful business onl...
# 654137     "  how many weeks can the onion juice stay ,...
# 720041     "  how to   "  get rid off of your unhappy p...
# ...                                                    ...
# 737509    .  what kind of bullying is there ?  is there...
# 1206740   .  what political and social theories from th...
# 20319     .  which is the best tour operator for south ...
# 181887    .  which sentences refer to events that were ...
# 1304977      .  why do we use units such as light years ?
# 792503                                .  why men harass ?
# 1151443   ...  are you qualified that we may believe yo...
# 1196897   ...  what are you doing with all this easy ma...
# 150532   ‪does anyone know of an ios email client that ...
# 495724   ‪how much do china or the usa will bid to buy ...
# 517764   ‪if a picture is worth a thousand words ,  doe...
# 1263890  ‪if an automated car violates traffic rules , ...
# 932272   ‪if you join the people your political leaders...
# 400329   ‪is theresa may the most stupid prime minister...
# 849182   ‪there are many lgbt couples trying to adopt k...
# 171612   ‪what are the best scientific evidences and id...
# 56896    ‪what in your opinion are the greatest opening...
# 756223   ‪what is the position of the eu regarding icos ?
# 82007    ‪where do i go to find people who will talk co...
# 113435   ⁠⁠is it bad to lay your motorcycle on its side...
# 56298    ⊂  {  }  is true while 1 ⊆  { 1 }  is false , ...
# 146277               -  6 . 175 is an irrational number ?
# 859955   ♣ why does winston finally give in to the ideo...
# 1185049  ⦁ what are the methods used to suppress or red...
# 415446   译文 who well be enter the next member of the st...
# 231111                               한국 고등학교는 몇시간 수업하니까 ?
# 814877           what is the complex compound sentence ?
# 916459   what are the best porn pictures serving websit...
# 1261734  ｈow do i find the negative solution of 4 ^ x  ...
# 344918   ￼￼assuming that a lightning bolt can be modell...
#
# [1362392 rows x 4 columns]
